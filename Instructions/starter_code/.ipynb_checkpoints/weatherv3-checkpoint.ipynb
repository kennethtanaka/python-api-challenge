# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Save config information.
#API call: http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID={APIKEY}
#API call: api.openweathermap.org/data/2.5/weather?q={city name}
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
#Ins_OpenWeatherDataFrame
#set up lists to hold reponse info
city_lon = []
city_lat =[]
city_temp = []
city_clouds = []
city_humid = []
city_windy = []
city_name = []

#counter used for record
counter = 1

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
    # Build partial query URL
        query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
        response = requests.get(query_url).json()
        city_lon.append(response['coord']['lon'])
        city_lat.append(response['coord']['lat'])
        city_temp.append(response['main']['temp'])
        city_clouds.append(response['clouds']['all'])
        city_humid.append(response['main']['humidity'])
        city_windy.append(response['wind']['speed'])
        city_name.append(response['name'])
        print(f"Processing Record {counter} | {city}")
        counter = counter + 1
        
        #pause python execution for one second
        time.sleep(1)
        
    #exception block will occur if there missing data in lists
    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 1 | phangnga
# Processing Record 2 | arraial do cabo
# Processing Record 3 | the valley
# Processing Record 4 | trairi
# Processing Record 5 | cayambe
# Processing Record 6 | te anau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 | tiksi
# Processing Record 8 | bluff
# Processing Record 9 | nampula
# Processing Record 10 | busselton
# Processing Record 11 | ribeira grande
# Processing Record 12 | khatanga
# Processing Record 13 | upernavik
# Processing Record 14 | praia da vitoria
# Processing Record 15 | tucuman
# City not found. Skipping...
# Processing Record 16 | macin
# Processing Record 17 | ushuaia
# Processing Record 18 | rikitea
# Processing Record 19 | sidmouth
# Processing Record 20 | dikson
# Processing Record 21 | byron bay
# Processing Record 22 | iqaluit
# City not found. Skipping...
# Processing Record 23 | cape town
# Processing Record 24 | mahebourg
# City not found. Skipping...
# Processing Record 25 | semirom
# Processing Record 26 | lagoa
# Processing Record 27 | carnarvon
# Processing Record 28 | mataura
# City not found. Skipping...
# Processing Record 29 | codrington
# Processing Record 30 | torbay
# Processing Record 31 | lebu
# Processing Record 32 | xining
# Processing Record 33 | fare
# Processing Record 34 | fenton
# Processing Record 35 | saint george
# Processing Record 36 | hobyo
# Processing Record 37 | biltine
# Processing Record 38 | grindavik
# Processing Record 39 | hilo
# Processing Record 40 | madison
# Processing Record 41 | anupgarh
# Processing Record 42 | kaniama
# Processing Record 43 | luderitz
# Processing Record 44 | bemidji
# Processing Record 45 | mar del plata
# Processing Record 46 | srednekolymsk
# Processing Record 47 | butaritari
# Processing Record 48 | yurgamysh
# Processing Record 49 | morehead
# Processing Record 50 | kyabe
# Processing Record 51 | bredasdorp
# Processing Record 52 | jamestown
# Processing Record 53 | santa rosa
# Processing Record 54 | albany
# City not found. Skipping...
# Processing Record 55 | castro
# Processing Record 56 | barrow
# Processing Record 57 | muli
# Processing Record 58 | yozgat
# Processing Record 59 | deputatskiy
# Processing Record 60 | new norfolk
# City not found. Skipping...
# Processing Record 61 | sitka
# Processing Record 62 | lompoc
# Processing Record 63 | punta arenas
# Processing Record 64 | vaini
# Processing Record 65 | turukhansk
# Processing Record 66 | birao
# Processing Record 67 | quatre cocos
# Processing Record 68 | ulladulla
# Processing Record 69 | ust-maya
# Processing Record 70 | port hardy
# Processing Record 71 | wanning
# Processing Record 72 | half moon bay
# Processing Record 73 | tuktoyaktuk
# Processing Record 74 | rocha
# City not found. Skipping...
# Processing Record 75 | kerouane
# Processing Record 76 | atuona
# Processing Record 77 | ambulu
# Processing Record 78 | roxana
# Processing Record 79 | manta
# Processing Record 80 | hammond
# Processing Record 81 | georgetown
# Processing Record 82 | sakaiminato
# City not found. Skipping...
# Processing Record 83 | talara
# Processing Record 84 | saint-philippe
# Processing Record 85 | mikuni
# Processing Record 86 | esperance
# Processing Record 87 | tasiilaq
# Processing Record 88 | itupiranga
# Processing Record 89 | bethel
# Processing Record 90 | port alfred
# Processing Record 91 | severo-kurilsk
# Processing Record 92 | nanortalik
# Processing Record 93 | kandrian
# Processing Record 94 | hobart
# Processing Record 95 | ostrovnoy
# Processing Record 96 | bulgan
# Processing Record 97 | padang
# Processing Record 98 | kapaa
# Processing Record 99 | olinda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 100 | mount gambier
# Processing Record 101 | kilindoni
# Processing Record 102 | hun
# Processing Record 103 | sabha
# City not found. Skipping...
# Processing Record 104 | geraldton
# Processing Record 105 | broome
# Processing Record 106 | provideniya
# Processing Record 107 | plouzane
# Processing Record 108 | avarua
# City not found. Skipping...
# Processing Record 109 | ha giang
# Processing Record 110 | ojinaga
# Processing Record 111 | los llanos de aridane
# Processing Record 112 | bonavista
# Processing Record 113 | norman wells
# Processing Record 114 | klaksvik
# Processing Record 115 | juntas
# Processing Record 116 | qaanaaq
# Processing Record 117 | grand gaube
# Processing Record 118 | yellowknife
# Processing Record 119 | hambantota
# City not found. Skipping...
# Processing Record 120 | moussoro
# Processing Record 121 | mata
# Processing Record 122 | oleggio
# Processing Record 123 | cherskiy
# Processing Record 124 | hasaki
# Processing Record 125 | puerto ayora
# Processing Record 126 | pevek
# Processing Record 127 | coquimbo
# Processing Record 128 | kitui
# Processing Record 129 | mayor pablo lagerenza
# Processing Record 130 | lasa
# Processing Record 131 | illapel
# Processing Record 132 | elat
# Processing Record 133 | boyabat
# Processing Record 134 | chuy
# Processing Record 135 | karasjok
# Processing Record 136 | tuatapere
# Processing Record 137 | kaitangata
# Processing Record 138 | meadow lake
# Processing Record 139 | saint anthony
# City not found. Skipping...
# Processing Record 140 | guerrero negro
# Processing Record 141 | ahuimanu
# Processing Record 142 | beringovskiy
# Processing Record 143 | royan
# Processing Record 144 | matara
# Processing Record 145 | les cayes
# Processing Record 146 | ucluelet
# Processing Record 147 | huescar
# Processing Record 148 | tamandare
# Processing Record 149 | benghazi
# Processing Record 150 | nikolskoye
# Processing Record 151 | kavaratti
# Processing Record 152 | hermanus
# Processing Record 153 | muyezerskiy
# Processing Record 154 | bozoum
# Processing Record 155 | ponta delgada
# Processing Record 156 | lamu
# Processing Record 157 | aklavik
# Processing Record 158 | saint-georges
# Processing Record 159 | kirs
# City not found. Skipping...
# Processing Record 160 | vostok
# Processing Record 161 | sao gabriel da cachoeira
# Processing Record 162 | lively
# Processing Record 163 | isangel
# Processing Record 164 | flinders
# City not found. Skipping...
# Processing Record 165 | dakar
# City not found. Skipping...
# Processing Record 166 | constitucion
# Processing Record 167 | atikokan
# Processing Record 168 | nanyang
# Processing Record 169 | east london
# Processing Record 170 | marakkanam
# Processing Record 171 | champerico
# Processing Record 172 | yuli
# Processing Record 173 | askarovo
# Processing Record 174 | natal
# Processing Record 175 | bahia blanca
# Processing Record 176 | umm lajj
# Processing Record 177 | dingzhou
# Processing Record 178 | maxixe
# Processing Record 179 | oxford
# Processing Record 180 | manitouwadge
# Processing Record 181 | mount isa
# Processing Record 182 | moose factory
# Processing Record 183 | majene
# Processing Record 184 | bathsheba
# Processing Record 185 | thompson
# Processing Record 186 | cockburn town
# Processing Record 187 | griffith
# Processing Record 188 | hetauda
# Processing Record 189 | hofn
# Processing Record 190 | progreso
# Processing Record 191 | aripuana
# Processing Record 192 | kavieng
# Processing Record 193 | whitley bay
# Processing Record 194 | coahuayana
# Processing Record 195 | salinopolis
# Processing Record 196 | buzmeyin
# Processing Record 197 | puerto carreno
# Processing Record 198 | langsa
# Processing Record 199 | sur
# Processing Record 200 | bam
# Processing Record 201 | mikhaylovka
# Processing Record 202 | pisco
# Processing Record 203 | arlit
# Processing Record 204 | hithadhoo
# City not found. Skipping...
# Processing Record 205 | khandyga
# City not found. Skipping...
# Processing Record 206 | mogadishu
# Processing Record 207 | la macarena
# Processing Record 208 | tuy hoa
# City not found. Skipping...
# Processing Record 209 | porto novo
# Processing Record 210 | grand-santi
# Processing Record 211 | port elizabeth
# Processing Record 212 | avera
# Processing Record 213 | san cristobal
# Processing Record 214 | bay roberts
# Processing Record 215 | turbat
# Processing Record 216 | husavik
# Processing Record 217 | mehamn
# Processing Record 218 | labuhan
# Processing Record 219 | san isidro
# Processing Record 220 | poum
# Processing Record 221 | ixtapa
# Processing Record 222 | kodiak
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 223 | eyl
# Processing Record 224 | kitimat
# Processing Record 225 | launceston
# Processing Record 226 | faanui
# Processing Record 227 | boa vista
# Processing Record 228 | barentu
# Processing Record 229 | dunedin
# Processing Record 230 | maningrida
# City not found. Skipping...
# Processing Record 231 | roald
# Processing Record 232 | mao
# Processing Record 233 | lumsden
# Processing Record 234 | chokurdakh
# Processing Record 235 | atar
# Processing Record 236 | treinta y tres
# Processing Record 237 | srivardhan
# Processing Record 238 | pindi bhattian
# Processing Record 239 | fortuna
# Processing Record 240 | bluffton
# Processing Record 241 | marathon
# Processing Record 242 | vorobyevka
# Processing Record 243 | kathmandu
# Processing Record 244 | gayny
# City not found. Skipping...
# Processing Record 245 | birjand
# Processing Record 246 | carutapera
# Processing Record 247 | grand-lahou
# Processing Record 248 | cardston
# Processing Record 249 | ranong
# City not found. Skipping...
# Processing Record 250 | asosa
# Processing Record 251 | yashan
# Processing Record 252 | matagami
# Processing Record 253 | barra do bugres
# Processing Record 254 | saldanha
# Processing Record 255 | ambon
# Processing Record 256 | cedar falls
# Processing Record 257 | leh
# Processing Record 258 | tazmalt
# Processing Record 259 | mabaruma
# Processing Record 260 | tautira
# Processing Record 261 | safranbolu
# Processing Record 262 | solnechnyy
# Processing Record 263 | lobva
# City not found. Skipping...
# Processing Record 264 | macia
# City not found. Skipping...
# Processing Record 265 | namatanai
# City not found. Skipping...
# Processing Record 266 | merauke
# Processing Record 267 | vardo
# Processing Record 268 | port blair
# City not found. Skipping...
# Processing Record 269 | marin
# Processing Record 270 | estevan
# City not found. Skipping...
# Processing Record 271 | chazuta
# Processing Record 272 | cairns
# Processing Record 273 | tilichiki
# Processing Record 274 | nalut
# Processing Record 275 | port hedland
# Processing Record 276 | college
# Processing Record 277 | krupanj
# Processing Record 278 | port-cartier
# Processing Record 279 | enshi
# Processing Record 280 | burgeo
# Processing Record 281 | kingaroy
# Processing Record 282 | bambous virieux
# Processing Record 283 | nioro
# Processing Record 284 | malanje
# Processing Record 285 | nanticoke
# City not found. Skipping...
# Processing Record 286 | panaba
# Processing Record 287 | sao joao da barra
# Processing Record 288 | urucui
# Processing Record 289 | zhangjiakou
# Processing Record 290 | kamenka
# Processing Record 291 | san rafael
# Processing Record 292 | sirjan
# Processing Record 293 | margate
# Processing Record 294 | nortelandia
# City not found. Skipping...
# Processing Record 295 | impfondo
# Processing Record 296 | hualmay
# Processing Record 297 | bull savanna
# Processing Record 298 | fairbanks
# Processing Record 299 | bangassou
# Processing Record 300 | longyearbyen
# Processing Record 301 | oktyabrskoye
# Processing Record 302 | nouadhibou
# Processing Record 303 | kloulklubed
# Processing Record 304 | pacific grove
# Processing Record 305 | beihai
# Processing Record 306 | lakes entrance
# Processing Record 307 | tura
# Processing Record 308 | kibala
# Processing Record 309 | sistranda
# Processing Record 310 | sao filipe
# Processing Record 311 | fort frances
# Processing Record 312 | muros
# Processing Record 313 | cayenne
# Processing Record 314 | leningradskiy
# Processing Record 315 | pitimbu
# Processing Record 316 | anloga
# Processing Record 317 | yatou
# City not found. Skipping...
# Processing Record 318 | kungurtug
# City not found. Skipping...
# Processing Record 319 | mayo
# Processing Record 320 | sao borja
# Processing Record 321 | camacha
# Processing Record 322 | marzuq
# Processing Record 323 | gladstone
# Processing Record 324 | ponta do sol
# Processing Record 325 | opuwo
# Processing Record 326 | henties bay
# Processing Record 327 | mbandaka
# Processing Record 328 | hamina
# Processing Record 329 | souillac
# Processing Record 330 | saskylakh
# City not found. Skipping...
# Processing Record 331 | cabedelo
# Processing Record 332 | vanavara
# Processing Record 333 | yelovo
# Processing Record 334 | chapais
# Processing Record 335 | kununurra
# Processing Record 336 | san vicente
# Processing Record 337 | rundu
# Processing Record 338 | luanda
# Processing Record 339 | lazaro cardenas
# Processing Record 340 | valday
# Processing Record 341 | lohja
# Processing Record 342 | farim
# City not found. Skipping...
# Processing Record 343 | lubango
# Processing Record 344 | loiza
# Processing Record 345 | rawson
# City not found. Skipping...
# Processing Record 346 | sisimiut
# Processing Record 347 | sarangani
# Processing Record 348 | antalaha
# Processing Record 349 | victoria
# Processing Record 350 | warmbad
# Processing Record 351 | itoman
# Processing Record 352 | huautla
# Processing Record 353 | hit
# Processing Record 354 | omboue
# Processing Record 355 | mizan teferi
# Processing Record 356 | nago
# Processing Record 357 | visnes
# Processing Record 358 | santa isabel do rio negro
# Processing Record 359 | baruun-urt
# Processing Record 360 | orocue
# Processing Record 361 | promyshlennaya
# Processing Record 362 | kodinsk
# Processing Record 363 | puerto escondido
# Processing Record 364 | barmer
# Processing Record 365 | agirish
# Processing Record 366 | bacolod
# Processing Record 367 | piacabucu
# Processing Record 368 | svetlogorsk
# City not found. Skipping...
# Processing Record 369 | anadyr
# Processing Record 370 | acapulco
# City not found. Skipping...
# Processing Record 371 | uddevalla
# Processing Record 372 | ketchikan
# Processing Record 373 | shahrud
# Processing Record 374 | shingu
# Processing Record 375 | junction city
# Processing Record 376 | la romana
# Processing Record 377 | lavrentiya
# Processing Record 378 | portree
# Processing Record 379 | tottori
# Processing Record 380 | eydhafushi
# Processing Record 381 | ahipara
# Processing Record 382 | viedma
# Processing Record 383 | zeya
# Processing Record 384 | airai
# Processing Record 385 | havelock
# Processing Record 386 | sola
# Processing Record 387 | zheleznodorozhnyy
# City not found. Skipping...
# Processing Record 388 | colares
# Processing Record 389 | port lincoln
# Processing Record 390 | murchison
# Processing Record 391 | makat
# Processing Record 392 | mackay
# Processing Record 393 | santiago
# City not found. Skipping...
# Processing Record 394 | izvoarele sucevei
# Processing Record 395 | verkhnyaya inta
# Processing Record 396 | lorengau
# Processing Record 397 | tigil
# Processing Record 398 | kisangani
# Processing Record 399 | hami
# Processing Record 400 | la ronge
# Processing Record 401 | roebourne
# Processing Record 402 | marsa matruh
# Processing Record 403 | quelimane
# Processing Record 404 | whitehorse
# Processing Record 405 | vila velha
# Processing Record 406 | kruisfontein
# Processing Record 407 | caravelas
# Processing Record 408 | vila
# Processing Record 409 | victor harbor
# Processing Record 410 | dinan
# Processing Record 411 | berlevag
# Processing Record 412 | ingham
# City not found. Skipping...
# Processing Record 413 | riberalta
# Processing Record 414 | rabo de peixe
# Processing Record 415 | olga
# Processing Record 416 | camrose
# Processing Record 417 | yulara
# Processing Record 418 | shaowu
# Processing Record 419 | jalalabad
# Processing Record 420 | ossora
# Processing Record 421 | khoy
# Processing Record 422 | bogorodskoye
# Processing Record 423 | ocala
# City not found. Skipping...
# Processing Record 424 | rio gallegos
# City not found. Skipping...
# Processing Record 425 | vao
# Processing Record 426 | bangolo
# Processing Record 427 | nykoping
# Processing Record 428 | tiarei
# Processing Record 429 | jumla
# Processing Record 430 | sinjai
# Processing Record 431 | rochester
# Processing Record 432 | nadym
# Processing Record 433 | yinchuan
# Processing Record 434 | necochea
# City not found. Skipping...
# Processing Record 435 | peterborough
# City not found. Skipping...
# Processing Record 436 | corn island
# Processing Record 437 | coihaique
# Processing Record 438 | kijang
# Processing Record 439 | ilulissat
# Processing Record 440 | kachug
# Processing Record 441 | tonota
# Processing Record 442 | lagunas
# Processing Record 443 | yerbogachen
# Processing Record 444 | ismailia
# Processing Record 445 | beroroha
# Processing Record 446 | bayeux
# Processing Record 447 | narsaq
# Processing Record 448 | boca do acre
# Processing Record 449 | san patricio
# Processing Record 450 | bilma
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 451 | palembang
# Processing Record 452 | ponnani
# Processing Record 453 | beloha
# Processing Record 454 | ukiah
# Processing Record 455 | touros
# Processing Record 456 | voh
# Processing Record 457 | samarai
# Processing Record 458 | maraa
# Processing Record 459 | klang
# Processing Record 460 | okawa
# Processing Record 461 | harrisonville
# City not found. Skipping...
# Processing Record 462 | kamsack
# Processing Record 463 | westport
# Processing Record 464 | wloszczowa
# Processing Record 465 | kapit
# Processing Record 466 | pochutla
# Processing Record 467 | tuburan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 468 | tual
# Processing Record 469 | mondlo
# Processing Record 470 | palu
# Processing Record 471 | thanh hoa
# City not found. Skipping...
# Processing Record 472 | prince george
# Processing Record 473 | vung tau
# Processing Record 474 | saint-pierre
# Processing Record 475 | calamar
# Processing Record 476 | de aar
# Processing Record 477 | ocean city
# Processing Record 478 | mozarlandia
# Processing Record 479 | cap-aux-meules
# Processing Record 480 | saint-gilles
# Processing Record 481 | quevedo
# Processing Record 482 | shache
# Processing Record 483 | sciacca
# City not found. Skipping...
# Processing Record 484 | goderich
# Processing Record 485 | bereda
# Processing Record 486 | maniitsoq
# Processing Record 487 | magdagachi
# Processing Record 488 | ternate
# City not found. Skipping...
# Processing Record 489 | itarema
# Processing Record 490 | beisfjord
# Processing Record 491 | naze
# Processing Record 492 | pokhara
# Processing Record 493 | saquarema
# Processing Record 494 | princeton
# Processing Record 495 | zonguldak
# Processing Record 496 | mahon
# Processing Record 497 | san juan bautista
# Processing Record 498 | riyadh
# City not found. Skipping...
# Processing Record 499 | calama
# Processing Record 500 | bobon
# Processing Record 501 | campo maior
# Processing Record 502 | zabol
# Processing Record 503 | san roque
# Processing Record 504 | tanout
# Processing Record 505 | faya
# Processing Record 506 | clyde
# Processing Record 507 | kabugao
# Processing Record 508 | ust-kuyga
# Processing Record 509 | harper
# Processing Record 510 | marawi
# Processing Record 511 | shar
# Processing Record 512 | marsh harbour
# Processing Record 513 | bambari
# Processing Record 514 | kangaatsiaq
# Processing Record 515 | port hawkesbury
# Processing Record 516 | toora-khem
# City not found. Skipping...
# Processing Record 517 | severodvinsk
# City not found. Skipping...
# Processing Record 518 | begusarai
# Processing Record 519 | sakaraha
# Processing Record 520 | warri
# Processing Record 521 | esna
# Processing Record 522 | bambanglipuro
# Processing Record 523 | new philadelphia
# Processing Record 524 | mecca
# Processing Record 525 | douentza
# Processing Record 526 | montevideo
# Processing Record 527 | belmonte
# Processing Record 528 | qaqortoq
# Processing Record 529 | kahului
# Processing Record 530 | majdanpek
# City not found. Skipping...
# Processing Record 531 | meulaboh
# Processing Record 532 | ningxiang
# Processing Record 533 | jiuquan
# Processing Record 534 | sechura
# Processing Record 535 | namtsy
# Processing Record 536 | rongcheng
# Processing Record 537 | smithers
# Processing Record 538 | altay
# Processing Record 539 | yalutorovsk
# Processing Record 540 | bronnoysund
# Processing Record 541 | atambua
# Processing Record 542 | pringsewu
# Processing Record 543 | chakia
# Processing Record 544 | cariamanga
# Processing Record 545 | suriapet
# Processing Record 546 | bojnurd
# Processing Record 547 | dingle
# Processing Record 548 | den helder
# Processing Record 549 | tecoanapa
# Processing Record 550 | anchorage
# Processing Record 551 | cajamar
# Processing Record 552 | askino
# Processing Record 553 | stromness
# Processing Record 554 | lumphat
# City not found. Skipping...
# Processing Record 555 | felipe carrillo puerto
# Processing Record 556 | berovo
# Processing Record 557 | hamilton
# Processing Record 558 | henderson
# Processing Record 559 | dera bugti
# Processing Record 560 | jam sahib
# City not found. Skipping...
# Processing Record 561 | katsuura

# %%
# display keys
response.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
pprint (response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 33.93, 'lon': 134.5},
#  'dt': 1577376819,
#  'id': 1865309,
#  'main': {'feels_like': 43.41,
#           'humidity': 87,
#           'pressure': 1003,
#           'temp': 53.69,
#           'temp_max': 55.4,
#           'temp_min': 53.01},
#  'name': 'Katsuura',
#  'sys': {'country': 'JP',
#          'id': 8027,
#          'sunrise': 1577397935,
#          'sunset': 1577433575,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 5000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 330, 'gust': 29.97, 'speed': 18.34}}

# %%
print(f"The temperature is: response ['main']['temp']")
# Out:
# The temperature is: response ['main']['temp']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame
weather_dict = {
    "name": city_name,
    "lat": city_lat,
    "lon": city_lon,   
    "temp": city_temp,
    "clouds": city_clouds,
    "humidity": city_humid, 
    "windy": city_windy
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#               name    lat    lon   temp  clouds  humidity  windy
# 0         Phangnga   8.45  98.53  75.90      20        88   2.24
# 1  Arraial do Cabo -22.97 -42.02  84.25      20        78  14.99
# 2       The Valley  18.22 -63.06  84.09      20        66  13.87
# 3           Trairi  -3.28 -39.27  93.70      12        38   8.90
# 4          Cayambe   0.04 -78.14  69.80      20        49   4.70

# %%
# Identify incomplete rows
weather_data.count()
# Out:
# name        561
# lat         561
# lon         561
# temp        561
# clouds      561
# humidity    561
# windy       561
# dtype: int64

# %%
#save to csv
weather_data.to_csv
# Out:
# <bound method NDFrame.to_csv of                 name    lat     lon   temp  clouds  humidity  windy
# 0           Phangnga   8.45   98.53  75.90      20        88   2.24
# 1    Arraial do Cabo -22.97  -42.02  84.25      20        78  14.99
# 2         The Valley  18.22  -63.06  84.09      20        66  13.87
# 3             Trairi  -3.28  -39.27  93.70      12        38   8.90
# 4            Cayambe   0.04  -78.14  69.80      20        49   4.70
# ..               ...    ...     ...    ...     ...       ...    ...
# 556         Hamilton  43.26  -79.87  36.03      90       100  12.75
# 557        Henderson  36.04 -114.98  41.54      90        65   9.17
# 558       Dera Bugti  29.03   69.15  55.02       0        24   2.37
# 559        Jam Sahib  26.30   68.63  59.00       0        54   6.91
# 560         Katsuura  33.93  134.50  53.69      75        87  18.34
#
# [561 rows x 7 columns]>

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Temperature")
plt.ylabel("Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["clouds"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["lat"], weather_data["windy"], marker="o")

# Incorporate the other graph properties
plt.title("City Wind Speed vs Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_SpeedInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# Written description of three observable trends based on the data:
#
# 1. Zero degrees (0°) latitude is the equator. The temperatures are the hottest for the cities nearest the equator and decreases as you move North away from the equator. Southern latitudes are expressed as negative number where -90° is at the South Pole. However, temperatures do not show the same decrease in temperature as you move South away from the equator.
# 2. Latitude has no impact on cloudiness.
# 3. Wind speed ranges between 0 and 10 mph for most cities in the world.
